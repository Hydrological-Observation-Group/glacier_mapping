# %% [markdown]
# #### validation dataset generation

# %%
import torch
import numpy as np 
from glob import glob 
import rasterio as rio
from notebooks import config  
from pyrsimg import imsShow 
from pyrsimg import img2patch

# %%
dir_val_scene = 'data/dset/dset_split/val/scene' 
dir_val_dem = 'data/dset/dset_split/val/dem' 
dir_val_truth = 'data/dset/dset_split/val/truth' 
dir_val_patch = 'data/dset/dset_split/val_patch' 
patch_size = 512  ## base patch size
# ## valset
paths_val_scene = sorted(glob(dir_val_scene+'/*.tif'))
paths_val_dem = sorted(glob(dir_val_dem+'/*.tif'))
paths_val_truth = sorted(glob(dir_val_truth+'/*.tif'))
paths_valset = list(zip(paths_val_scene, paths_val_dem, paths_val_truth))
print(len(paths_valset))   
paths_valset[4]
# Out:
# 13
# ('data/dset/dset_split/val/scene/l7_scene_08.tif',
#  'data/dset/dset_split/val/dem/l7_scene_08_dem.tif',
#  'data/dset/dset_split/val/truth/l7_scene_08_truth.tif')

# %%
paths_valset = list(zip(paths_val_scene, paths_val_dem, paths_val_truth))
paths_valset[2]
# Out:
# ('data/dset/dset_split/val/scene/l5_scene_11.tif',
#  'data/dset/dset_split/val/dem/l5_scene_11_dem.tif',
#  'data/dset/dset_split/val/truth/l5_scene_11_truth.tif')

# %%
'''generate validation patches (include patch,dem,truth)'''
paths_valset = list(zip(paths_val_scene, paths_val_dem, paths_val_truth))
dset_list = []
for path_scene, path_dem, path_truth in paths_valset:
    scene_val_arr = rio.open(path_scene).read()
    dem_val_arr = rio.open(path_dem).read()
    truth_val_arr = rio.open(path_truth).read()
    scene_dem_truth_arr = np.concatenate([scene_val_arr, 
                                        dem_val_arr, 
                                        truth_val_arr], 
                                        axis=0)
    img2patches = img2patch(img = scene_dem_truth_arr.transpose(1,2,0), 
                            patch_size = patch_size, 
                            edge_overlay = 50,   ## 50 for patch_512, 100 for patch_1024
                            )  
    patch_list = img2patches.toPatch()
    dset_list.extend(patch_list)
    # break 
print(len(dset_list))
# Out:
# 208

# %%
'''---- save validation data (patch, dem, truth)----'''
dir_valset = f'data/dset/dset_split/val_patch/patch_{patch_size}'
for id_patch, patch_pdem_ptruth in enumerate(dset_list):
    print(id_patch)
    ## save as float16 to save space
    patch_ = torch.from_numpy(patch_pdem_ptruth).permute(2,0,1)
    patch_ = patch_.to(dtype=torch.float16)     
    path_save = dir_valset+'/patch_pdem_ptruth_'+ str(id_patch).rjust(4,'0')+'.pt'
    print(path_save)    
    torch.save((patch_), path_save)
    # break
# Out:
# 0
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0000.pt
# 1
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0001.pt
# 2
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0002.pt
# 3
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0003.pt
# 4
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0004.pt
# 5
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0005.pt
# 6
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0006.pt
# 7
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0007.pt
# 8
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0131.pt
# 132
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0132.pt
# 133
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0133.pt
# 134
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0134.pt
# 135
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0135.pt
# 136
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0136.pt
# 137
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0137.pt
# 138
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0138.pt
# 139
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0139.pt
# 140
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0140.pt
# 141
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0141.pt
# 142
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0142.pt
# 143
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0143.pt
# 144
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0144.pt
# 145
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0145.pt
# 146
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0146.pt
# 147
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0147.pt
# 148
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0148.pt
# 149
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0149.pt
# 150
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0150.pt
# 151
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0151.pt
# 152
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0152.pt
# 153
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0153.pt
# 154
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0154.pt
# 155
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0155.pt
# 156
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0156.pt
# 157
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0157.pt
# 158
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0158.pt
# 159
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0159.pt
# 160
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0160.pt
# 161
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0161.pt
# 162
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0162.pt
# 163
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0163.pt
# 164
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0164.pt
# 165
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0165.pt
# 166
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0166.pt
# 167
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0167.pt
# 168
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0168.pt
# 169
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0169.pt
# 170
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0170.pt
# 171
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0171.pt
# 172
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0172.pt
# 173
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0173.pt
# 174
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0174.pt
# 175
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0175.pt
# 176
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0176.pt
# 177
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0177.pt
# 178
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0178.pt
# 179
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0179.pt
# 180
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0180.pt
# 181
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0181.pt
# 182
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0182.pt
# 183
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0183.pt
# 184
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0184.pt
# 185
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0185.pt
# 186
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0186.pt
# 187
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0187.pt
# 188
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0188.pt
# 189
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0189.pt
# 190
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0190.pt
# 191
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0191.pt
# 192
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0192.pt
# 193
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0193.pt
# 194
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0194.pt
# 195
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0195.pt
# 196
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0196.pt
# 197
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0197.pt
# 198
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0198.pt
# 199
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0199.pt
# 200
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0200.pt
# 201
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0201.pt
# 202
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0202.pt
# 203
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0203.pt
# 204
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0204.pt
# 205
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0205.pt
# 206
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0206.pt
# 207
# data/dset/dset_split/val_patch/patch_512/patch_pdem_ptruth_0207.pt

# %% [markdown]
# ### load data and check

# %%
## load data
paths_patch_valset = sorted(glob(dir_valset + '/*'))
patch_list_valset = [torch.load(path, weights_only=True) for path in paths_patch_valset]
print(len(patch_list_valset))
# Out:
# 208

# %%
id = np.random.randint(0, len(patch_list_valset))
patch_pdem_ptruth = patch_list_valset[id].numpy().transpose(1,2,0)  ##(patches,pdem,ptruth)
patch = patch_pdem_ptruth[:,:,0:6].astype(np.float32)
pdem = patch_pdem_ptruth[:,:, 6:7].astype(np.float32)  
ptruth = patch_pdem_ptruth[:, :, -1:].astype(np.int8)  
patch_pdem_ptruth_ = [patch, pdem, ptruth]  
imgs_name = ['patch', 'pdem', 'ptruth']  
clip_list = [2,2,0]  
col_bands_list = [(2,1,0), (0,0,0), (0,0,0)]
imsShow(img_list=patch_pdem_ptruth_, 
            img_name_list=imgs_name,
            clip_list=clip_list, 
            color_bands_list=col_bands_list,
            figsize=(11,3))
